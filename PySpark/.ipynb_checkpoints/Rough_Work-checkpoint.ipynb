# %%
from pyspark.sql.dataframe import DataFrame
from pyspark.sql.window import Window
from pyspark.sql.functions import col, when, avg, lag, row_number, mean, stddev, sum, year, month

# %%
full_grouped_file_path = "hdfs:///data/covid/staging/full_grouped/part-00000-601599f8-be87-42e1-9b16-0020e80d7820-c000.snappy.parquet"
worldometer_data_file_path = "hdfs:///data/covid/staging/worldometer_data/part-00000-65892e24-b897-4a4c-9026-5931b3aa0a78-c000.snappy.parquet"

# %%
def read_data(file_path):
    return spark.read.parquet(file_path)

# %%
full_grouped_df = read_data(full_grouped_file_path)
worldometer_df = read_data(worldometer_data_file_path)

# %%
def daily_country_analysis(df: DataFrame) -> DataFrame:
    df = df.groupBy(["Country_Region", "Date"]).agg({"deaths": "sum", "confirmed": "sum"})
    df = df.withColumnsRenamed({"sum(confirmed)": "Confirmed", "sum(deaths)": "Deaths"})
    df = df.filter(df['Confirmed'] != 0)
    df = df.withColumn("Death_Percentage", (df.Deaths / df.Confirmed) * 100)
    return df

# %%
def daily_global_death_analysis(df: DataFrame) -> DataFrame:
    df = df.groupBy("Date").agg({"deaths": "sum", "confirmed": "sum"})
    df = df.withColumnsRenamed({"sum(confirmed)": "Confirmed", "sum(deaths)": "Deaths"})
    df = df.filter(df["Confirmed"] != 0)
    df = df.withColumn("Death_Percentage", (df.Deaths / df.Confirmed) * 100)
    return df

# %%
daily_global_death_analysis(full_grouped_df).take(100)
# Out:
# [Row(Date=datetime.date(2020, 7, 24), Confirmed=15791645, Deaths=639650, Death_Percentage=4.050559647205849),
#  Row(Date=datetime.date(2020, 4, 30), Confirmed=3268876, Deaths=234704, Death_Percentage=7.179960328871453),
#  Row(Date=datetime.date(2020, 3, 7), Confirmed=105312, Deaths=3553, Death_Percentage=3.373784563962322),
#  Row(Date=datetime.date(2020, 3, 13), Confirmed=146008, Deaths=5406, Death_Percentage=3.702536847296039),
#  Row(Date=datetime.date(2020, 2, 4), Confirmed=23898, Deaths=492, Death_Percentage=2.0587496861662067),
#  Row(Date=datetime.date(2020, 2, 15), Confirmed=68765, Deaths=1666, Death_Percentage=2.42274412855377),
#  Row(Date=datetime.date(2020, 5, 23), Confirmed=5322253, Deaths=343385, Death_Percentage=6.451872919231762),
#  Row(Date=datetime.date(2020, 2, 12), Confirmed=46561, Deaths=1118, Death_Percentage=2.401151178024527),
#  Row(Date=datetime.date(2020, 5, 8), Confirmed=3941935, Deaths=276304, Death_Percentage=7.009349469232749),
#  Row(Date=datetime.date(2020, 5, 24), Confirmed=5417579, Deaths=346525, Death_Percentage=6.396307280429136),
#  Row(Date=datetime.date(2020, 6, 4), Confirmed=6647861, Deaths=392218, Death_Percentage=5.899912768934248),
#  Row(Date=datetime.date(2020, 4, 29), Confirmed=3185195, Deaths=228742, Death_Percentage=7.181412754949069),
#  Row(Date=datetime.date(2020, 5, 10), Confirmed=4104027, Deaths=284135, Death_Percentage=6.92332189822338),
#  Row(Date=datetime.date(2020, 1, 25), Confirmed=1434, Deaths=42, Death_Percentage=2.928870292887029),
#  Row(Date=datetime.date(2020, 4, 23), Confirmed=2719327, Deaths=194727, Death_Percentage=7.160852666854703),
#  Row(Date=datetime.date(2020, 5, 19), Confirmed=4900702, Deaths=324441, Death_Percentage=6.620296439163205),
#  Row(Date=datetime.date(2020, 6, 10), Confirmed=7387517, Deaths=417441, Death_Percentage=5.650626590774681),
#  Row(Date=datetime.date(2020, 7, 12), Confirmed=12914636, Deaths=568993, Death_Percentage=4.405799745343191),
#  Row(Date=datetime.date(2020, 2, 21), Confirmed=76206, Deaths=2250, Death_Percentage=2.952523423352492),
#  Row(Date=datetime.date(2020, 5, 6), Confirmed=3761332, Deaths=265327, Death_Percentage=7.054070207043675),
#  Row(Date=datetime.date(2020, 5, 21), Confirmed=5110064, Deaths=334112, Death_Percentage=6.538313414469956),
#  Row(Date=datetime.date(2020, 6, 28), Confirmed=10117227, Deaths=502357, Death_Percentage=4.965362544499595),
#  Row(Date=datetime.date(2020, 3, 3), Confirmed=92241, Deaths=3154, Death_Percentage=3.419303780314611),
#  Row(Date=datetime.date(2020, 2, 27), Confirmed=82034, Deaths=2810, Death_Percentage=3.4254089767657314),
#  Row(Date=datetime.date(2020, 4, 20), Confirmed=2478258, Deaths=173965, Death_Percentage=7.019648478891222),
#  Row(Date=datetime.date(2020, 1, 24), Confirmed=941, Deaths=26, Death_Percentage=2.763018065887354),
#  Row(Date=datetime.date(2020, 2, 19), Confirmed=75030, Deaths=2123, Death_Percentage=2.8295348527255766),
#  Row(Date=datetime.date(2020, 4, 9), Confirmed=1584249, Deaths=101279, Death_Percentage=6.392871322626684),
#  Row(Date=datetime.date(2020, 4, 17), Confirmed=2250439, Deaths=157481, Death_Percentage=6.997790208932568),
#  Row(Date=datetime.date(2020, 3, 5), Confirmed=97331, Deaths=3342, Death_Percentage=3.4336439572181527),
#  Row(Date=datetime.date(2020, 3, 6), Confirmed=101274, Deaths=3454, Death_Percentage=3.410549598119952),
#  Row(Date=datetime.date(2020, 5, 9), Confirmed=4027781, Deaths=280569, Death_Percentage=6.9658454618063885),
#  Row(Date=datetime.date(2020, 6, 18), Confirmed=8466978, Deaths=454700, Death_Percentage=5.37027496705436),
#  Row(Date=datetime.date(2020, 3, 25), Confirmed=475706, Deaths=21793, Death_Percentage=4.581190903625348),
#  Row(Date=datetime.date(2020, 5, 27), Confirmed=5699664, Deaths=357119, Death_Percentage=6.265614955548257),
#  Row(Date=datetime.date(2020, 7, 19), Confirmed=14506845, Deaths=606159, Death_Percentage=4.178434387353005),
#  Row(Date=datetime.date(2020, 5, 12), Confirmed=4263867, Deaths=293155, Death_Percentage=6.8753317118005794),
#  Row(Date=datetime.date(2020, 2, 1), Confirmed=12038, Deaths=259, Death_Percentage=2.1515201860774216),
#  Row(Date=datetime.date(2020, 7, 18), Confirmed=14292198, Deaths=602130, Death_Percentage=4.212997888778199),
#  Row(Date=datetime.date(2020, 6, 20), Confirmed=8805336, Deaths=465222, Death_Percentage=5.2834099686826255),
#  Row(Date=datetime.date(2020, 7, 17), Confirmed=14054563, Deaths=596503, Death_Percentage=4.244194572253865),
#  Row(Date=datetime.date(2020, 2, 10), Confirmed=42633, Deaths=1013, Death_Percentage=2.37609363638496),
#  Row(Date=datetime.date(2020, 3, 27), Confirmed=603066, Deaths=28318, Death_Percentage=4.695671783851187),
#  Row(Date=datetime.date(2020, 7, 7), Confirmed=11833034, Deaths=544054, Death_Percentage=4.597755740412814),
#  Row(Date=datetime.date(2020, 7, 11), Confirmed=12721968, Deaths=565039, Death_Percentage=4.441443336439771),
#  Row(Date=datetime.date(2020, 2, 5), Confirmed=27643, Deaths=564, Death_Percentage=2.040299533335745)]

# %%
worldometer_df.take(1)
# Out:
# [Row(Country_Region='USA', Continent='North America', Population=331198130, TotalCases=5032179, NewCases=0, TotalDeaths=162804, NewDeaths=0, TotalRecovered=2576668, NewRecovered=0, ActiveCases=2292707, Serious,Critical=18296, Tot_Cases_1M_pop=15194.0, Deaths_1M_pop=492.0, TotalTests=63139605, Tests_1M_pop=190640.0, WHO_Region='Americas')]

# %%
full_grouped_df.take(1)
# Out:
# [Row(Date=datetime.date(2020, 1, 22), Country_Region='Afghanistan', Confirmed=0, Deaths=0, Recovered=0, Active=0, New_cases=0, New_deaths=0, New_recovered=0, WHO_Region='Eastern Mediterranean')]

# %%
def continent_wise_death_analysis(
    full_grouped_df: DataFrame, worldometer_df: DataFrame
) -> DataFrame:
    df = full_grouped_df.join(worldometer_df, "Country_Region")
    df = df.groupBy("Continent").agg({"deaths": "sum", "confirmed": "sum"})
    df = df.withColumnsRenamed({"sum(confirmed)": "Confirmed", "sum(deaths)": "Deaths"})
    df = df.filter(df["Confirmed"] != 0)
    df = df.withColumn("Death_Percentage", (df.Deaths / df.Confirmed) * 100)
    return df

# %%
continent_wise_death_analysis(full_grouped_df, worldometer_df).take(10)
# Out:
# [Row(Continent='Europe', Confirmed=194318876, Deaths=14689301, Death_Percentage=7.559379357463966),
#  Row(Continent='Africa', Confirmed=26916623, Deaths=682067, Death_Percentage=2.53399915732371),
#  Row(Continent='Australia/Oceania', Confirmed=1139677, Deaths=13570, Death_Percentage=1.1906882388606597),
#  Row(Continent='North America', Confirmed=33282136, Deaths=2666043, Death_Percentage=8.010432383306169),
#  Row(Continent='South America', Confirmed=144631846, Deaths=5681838, Death_Percentage=3.9284833576693754),
#  Row(Continent='Asia', Confirmed=155784969, Deaths=3882965, Death_Percentage=2.4925158216002212)]

# %%
def country_with_highest_death_percentage(df: DataFrame) -> DataFrame:
    df = df.groupBy(["Country_Region"]).agg({"deaths": "sum", "confirmed": "sum"})
    df = df.withColumnsRenamed({"sum(confirmed)": "Confirmed", "sum(deaths)": "Deaths"})
    df = df.filter(df["Confirmed"] != 0)
    df = df.withColumn("Death_Percentage", (df.Deaths / df.Confirmed) * 100)
    return df.limit(1)

# %%
country_with_highest_death_percentage(full_grouped_df).show()
# Out:
# +--------------+---------+------+-----------------+
# |Country_Region|Confirmed|Deaths| Death_Percentage|
# +--------------+---------+------+-----------------+
# |          Chad|    64226|  5523|8.599321147198953|
# +--------------+---------+------+-----------------+

# %%
from pyspark.sql import functions as sf

def countries_with_most_deaths_per_capita(
    full_grouped_df: DataFrame, worldometer_df: DataFrame
)-> DataFrame:
    df = full_grouped_df.join(worldometer_df, "Country_Region")
    df = df.groupBy(["Country_Region"]).agg({"deaths": "sum", "confirmed": "sum", "population": "first"})
    df = df.withColumnsRenamed({"sum(confirmed)": "Confirmed", "sum(deaths)": "Deaths", "first(population)": "Population"})
    df = df.withColumn("Deaths_Per_Capita",  df.Deaths/ df.Population)
    df = df.sort(df.Deaths_Per_Capita.desc())
    return df.limit(10)

# %%
countries_with_most_deaths_per_capita(full_grouped_df, worldometer_df).show(10, truncate=False)
# Out:
# +--------------+---------+-------+----------+--------------------+
# |Country_Region|Confirmed|Deaths |Population|Deaths_Per_Capita   |
# +--------------+---------+-------+----------+--------------------+
# |San Marino    |74949    |5086   |33938     |0.1498615121692498  |
# |Belgium       |6281116  |963679 |11594739  |0.08311347068700727 |
# |Andorra       |94404    |5423   |77278     |0.0701752115737985  |
# |Spain         |27404045 |3033030|46756648  |0.06486842256100138 |
# |Italy         |26745145 |3707717|60452568  |0.06133266332043992 |
# |France        |21210926 |3048524|65288306  |0.04669326234318286 |
# |Sweden        |4973160  |448913 |10105596  |0.044422219134823915|
# |Netherlands   |5167516  |622314 |17138756  |0.03631033664286953 |
# |Ireland       |2571918  |161948 |4943200   |0.032761773749797704|
# |Switzerland   |3696604  |207858 |8660952   |0.023999440246291633|
# +--------------+---------+-------+----------+--------------------+

# %%
def confirmed_cases_per_1000_population(df: DataFrame) -> DataFrame:
    df = df.withColumn(
        "Confirmed_Cases_Per_1000_Population", (df.TotalCases / df.Population) * 1000
    )
    df = df.select('Country_Region','TotalCases','Population','Confirmed_Cases_Per_1000_Population')
    return df

# %%
confirmed_cases_per_1000_population(worldometer_df).show(10, truncate=False)
# Out:
# +--------------+----------+----------+-----------------------------------+
# |Country_Region|TotalCases|Population|Confirmed_Cases_Per_1000_Population|
# +--------------+----------+----------+-----------------------------------+
# |USA           |5032179   |331198130 |15.193862960518526                 |
# |Brazil        |2917562   |212710692 |13.716104125127853                 |
# |India         |2025409   |1381344997|1.4662586134519442                 |
# |Russia        |871894    |145940924 |5.974294091765514                  |
# |South Africa  |538184    |59381566  |9.063149328193871                  |
# |Mexico        |462690    |129066160 |3.5849056019021566                 |
# |Peru          |455409    |33016319  |13.793451656436927                 |
# |Chile         |366671    |19132514  |19.164810228284686                 |
# |Colombia      |357710    |50936262  |7.022698289089215                  |
# |Spain         |354530    |46756648  |7.5824511628806235                 |
# +--------------+----------+----------+-----------------------------------+
# only showing top 10 rows

# %%
from pyspark.sql.functions import col, when

def active_cases_per_1000_population(df: DataFrame) -> DataFrame:
    df = df.withColumn(
        "Active_Cases_Per_1000_Population", 
        when(
            col("Population") > 0,
            (col("ActiveCases") / col("Population")) * 1000
        ).otherwise(None)    
    )
    df = df.select(
        "Country_Region",
        "ActiveCases",
        "Population",
        "Active_Cases_Per_1000_Population",
    )
    return df

# %%
active_cases_per_1000_population(worldometer_df).show(207, truncate=False)
# Out:
# +----------------------+-----------+----------+--------------------------------+
# |Country_Region        |ActiveCases|Population|Active_Cases_Per_1000_Population|
# +----------------------+-----------+----------+--------------------------------+
# |USA                   |2292707    |331198130 |6.922463602074082               |
# |Brazil                |771258     |212710692 |3.625854406980163               |
# |India                 |606387     |1381344997|0.43898302112574994             |
# |Russia                |180931     |145940924 |1.2397550669200916              |
# |South Africa          |141264     |59381566  |2.378920084391173               |
# |Mexico                |103325     |129066160 |0.8005584112830195              |
# |Peru                  |124648     |33016319  |3.7753451558303635              |
# |Chile                 |16614      |19132514  |0.8683647115062871              |
# |Colombia              |153416     |50936262  |3.0119210553770124              |
# |Spain                 |0          |46756648  |0.0                             |
# |Iran                  |24678      |84097623  |0.29344467916768585             |
# |UK                    |0          |67922029  |0.0                             |
# |Saudi Arabia          |34082      |34865919  |0.9775161813460301              |
# |Pakistan              |19770      |221295851 |0.08933741826004682             |
# |Bangladesh            |102521     |164851401 |0.6218994766080271              |
# |Italy                 |12694      |60452568  |0.2099828083399203              |
# |Turkey                |10921      |84428331  |0.12935231421310459             |
# |Argentina             |124092     |45236884  |2.7431597631702487              |
# |Germany               |9758       |83811260  |0.11642826990072695             |
# |France                |82861      |65288306  |1.2691553063116692              |
# |Iraq                  |34417      |40306025  |0.8538921910558036              |
# |Philippines           |50473      |109722719 |0.4600050058912594              |
# |Indonesia             |37587      |273808365 |0.1372748418405698              |
# |Canada                |6489       |37775022  |0.17178017791756678             |
# |Qatar                 |3083       |2807805   |1.098010723679173               |
# |Kazakhstan            |26013      |18798667  |1.3837683278287762              |
# |Egypt                 |41157      |102516525 |0.4014669830059105              |
# |Ecuador               |13342      |17668824  |0.7551153376138672              |
# |Bolivia               |55585      |11688459  |4.7555456198289265              |
# |Sweden                |0          |10105596  |0.0                             |
# |Oman                  |9311       |5118446   |1.8191068148418486              |
# |Israel                |25556      |9197590   |2.778553947284017               |
# |Ukraine               |32465      |43705858  |0.742806605009333               |
# |Dominican Republic    |34751      |10858648  |3.2003063364794584              |
# |Panama                |24186      |4321282   |5.596950164326235               |
# |Belgium               |43638      |11594739  |3.7636034756797887              |
# |Kuwait                |7966       |4276658   |1.8626694021359669              |
# |Belarus               |4167       |9449001   |0.4409990008467562              |
# |UAE                   |5752       |9902079   |0.5808881145060547              |
# |Romania               |26337      |19224023  |1.3700046030947841              |
# |Netherlands           |0          |17138756  |0.0                             |
# |Singapore             |6497       |5854932   |1.1096627595333302              |
# |Guatemala             |10150      |17946899  |0.565557314386179               |
# |Portugal              |12478      |10193593  |1.224102237552549               |
# |Poland                |12099      |37842302  |0.31972156450736006             |
# |Nigeria               |11884      |206606300 |0.05752002722085435             |
# |Honduras              |37559      |9919704   |3.786302494509917               |
# |Bahrain               |2788       |1706669   |1.6335915165740984              |
# |Japan                 |12360      |126435859 |0.09775707696975428             |
# |Armenia               |7491       |2963811   |2.5274891010256724              |
# |Ghana                 |3059       |31133483  |0.09825434565095079             |
# |Tanzania              |305        |59886383  |0.005092977480373126            |
# |Taiwan                |27         |23821199  |0.0011334442065657568           |
# |Comoros               |49         |871326    |0.05623612746549512             |
# |Burundi               |90         |11922216  |0.007548932178380261            |
# |Myanmar               |43         |54446389  |7.897677107659058E-4            |
# |Mauritius             |0          |1271985   |0.0                             |
# |Isle of Man           |0          |85078     |0.0                             |
# |Mongolia              |33         |3283344   |0.010050728769206029            |
# |Eritrea               |57         |3551175   |0.01605102536484403             |
# |Guadeloupe            |86         |400131    |0.21492961055254403             |
# |Martinique            |163        |375235    |0.4343944461470811              |
# |Faeroe Islands        |74         |48882     |1.5138496788183788              |
# |Aruba                 |146        |106812    |1.3668876156237126              |
# |Cambodia              |33         |16741375  |0.0019711642562214872           |
# |Trinidad and Tobago   |67         |1399950   |0.04785885210186078             |
# |Cayman Islands        |0          |65798     |0.0                             |
# |Gibraltar             |6          |33690     |0.17809439002671418             |
# |Papua New Guinea      |107        |8963009   |0.01193795521124658             |
# |Sint Maarten          |80         |42924     |1.8637592023110614              |
# |Bermuda               |4          |62254     |0.06425289941208596             |
# |Brunei                |0          |437893    |0.0                             |
# |Barbados              |26         |287411    |0.09046278674093894             |
# |Turks and Caicos      |88         |38768     |2.269913330581923               |
# |Seychelles            |2          |98408     |0.020323550930818633            |
# |Monaco                |16         |39270     |0.40743570155334863             |
# |Bhutan                |12         |772443    |0.015535126863729749            |
# |Antigua and Barbuda   |13         |98010     |0.1326395265789205              |
# |Liechtenstein         |3          |38139     |0.07865963973885                |
# |Belize                |53         |398312    |0.13306151961276586             |
# |French Polynesia      |2          |281072    |0.007115614504468606            |
# |St. Vincent Grenadines|10         |110976    |0.09010957324106113             |
# |Saint Martin          |9          |38729     |0.23238400165250844             |
# |Macao                 |0          |650193    |0.0                             |
# |Curaçao               |2          |164161    |0.012183161652280384            |
# |Fiji                  |8          |897095    |0.008917673156131737            |
# |Saint Lucia           |1          |183712    |0.005443302560529524            |
# |Timor-Leste           |1          |1320812   |7.571100201996954E-4            |
# |Grenada               |1          |112576    |0.008882888004548038            |
# |New Caledonia         |0          |285769    |0.0                             |
# |Laos                  |1          |7285750   |1.3725422914593555E-4           |
# |Dominica              |0          |72004     |0.0                             |
# |Saint Kitts and Nevis |1          |53237     |0.018783928470800383            |
# |Greenland             |0          |56780     |0.0                             |
# |Montserrat            |2          |4992      |0.4006410256410256              |
# |Caribbean Netherlands |6          |26247     |0.22859755400617213             |
# |Falkland Islands      |0          |3489      |0.0                             |
# +----------------------+-----------+----------+--------------------------------+
# only showing top 207 rows

# %%
def top_10_country_with_highest_infection_rate(df: DataFrame) -> DataFrame:
    df = df.sort("Active_Cases_Per_1000_Population", ascending=False)
    df = df.withColumnRenamed("Active_Cases_Per_1000_Population","Infection_Rate")
    return df.limit(10)

# %%
df = active_cases_per_1000_population(worldometer_df)
top_10_country_with_highest_infection_rate(df).show()
# Out:
# +------------------+-----------+----------+------------------+
# |    Country_Region|ActiveCases|Population|    Infection_Rate|
# +------------------+-----------+----------+------------------+
# |               USA|    2292707| 331198130| 6.922463602074082|
# |            Panama|      24186|   4321282| 5.596950164326235|
# |           Bolivia|      55585|  11688459|4.7555456198289265|
# |          Honduras|      37559|   9919704| 3.786302494509917|
# |              Peru|     124648|  33016319|3.7753451558303635|
# |           Belgium|      43638|  11594739|3.7636034756797887|
# |            Brazil|     771258| 212710692| 3.625854406980163|
# |          Maldives|       1936|    541448| 3.575597287274124|
# |Dominican Republic|      34751|  10858648|3.2003063364794584|
# |          Colombia|     153416|  50936262|3.0119210553770124|
# +------------------+-----------+----------+------------------+

# %%
def who_region_ranking(df: DataFrame) -> DataFrame:
    df = df.groupBy(["WHO_Region"]).agg({'Population': 'sum', 'ActiveCases':'sum'})
    df = df.withColumnsRenamed({'sum(ActiveCases)': 'ActiveCases', 'sum(Population)': 'Population'})
    df = df.withColumn(
        'Infection_Rate',
        when(
            col('Population') > 0,
            (col('ActiveCases') / col('Population')) * 1000
        ).otherwise(None)
    )
    return df

# %%
who_region_ranking(worldometer_df).show()
# Out:
# +--------------------+-----------+----------+-------------------+
# |          WHO_Region|ActiveCases|Population|     Infection_Rate|
# +--------------------+-----------+----------+-------------------+
# |              Europe|     566295| 927733876| 0.6104067283191458|
# |              Africa|     232162|1118461393|0.20757265423107904|
# |      WesternPacific|      80820| 522144861| 0.1547846316924682|
# |      South-EastAsia|     755194|1997512597|0.37806720274715744|
# |             Unknown|       4838|   9681369|0.49972271483506103|
# |            Americas|    3808482|1018879504| 3.7379120740463927|
# |EasternMediterranean|     223396| 732007690|0.30518258626490663|
# +--------------------+-----------+----------+-------------------+

# %%
from pyspark.sql.functions import col, when

def recovered_percentage_per_country(df: DataFrame) -> DataFrame:
    df = df.withColumn(
        "Recovery_Rate",
        when(col("TotalCases") > 0, (col("TotalRecovered") / col("TotalCases")) * 100),
    )
    return df.select("Country_Region", "TotalCases", "TotalRecovered", "Recovery_Rate")

# %%
recovered_percentage_per_country(worldometer_df).show(100)
# Out:
# [Stage 4:>                                                          (0 + 1) / 1]
# +--------------------+----------+--------------+------------------+
# |      Country_Region|TotalCases|TotalRecovered|     Recovery_Rate|
# +--------------------+----------+--------------+------------------+
# |                 USA|   5032179|       2576668|51.203822439543586|
# |              Brazil|   2917562|       2047660| 70.18394124957756|
# |               India|   2025409|       1377384|   68.005227586132|
# |              Russia|    871894|        676357|  77.5733059293905|
# |        South Africa|    538184|        387316| 71.96720824104767|
# |              Mexico|    462690|        308848| 66.75052410901468|
# |                Peru|    455409|        310337| 68.14467873933103|
# |               Chile|    366671|        340168| 92.77199451279212|
# |            Colombia|    357710|        192355|53.774006877079195|
# |               Spain|    354530|             0|               0.0|
# |                Iran|    320117|        277463| 86.67549677149292|
# |                  UK|    308134|             0|               0.0|
# |        Saudi Arabia|    284226|        247089| 86.93398914947964|
# |            Pakistan|    281863|        256058| 90.84484306205496|
# |          Bangladesh|    249651|        143824| 57.61002359293573|
# |               Italy|    249204|        201323| 80.78642397393301|
# |              Turkey|    237265|        220546| 92.95344867553158|
# |            Bulgaria|     13014|          7374|56.662056247118485|
# |          Madagascar|     12526|         10148| 81.01548778540636|
# |               Sudan|     11780|          6194| 52.58064516129032|
# |     North Macedonia|     11399|          7480| 65.61979120975523|
# |             Senegal|     10715|          7101| 66.27158189454036|
# |              Norway|      9468|          8857| 93.54668356569498|
# |                 DRC|      9309|          8048| 86.45396927704371|
# |            Malaysia|      9038|          8713| 96.40407169727816|
# |       French Guiana|      8127|          7240| 89.08576350436816|
# |               Gabon|      7787|          5609| 72.03030692179273|
# |          Tajikistan|      7665|          6443| 84.05740378343118|
# |              Guinea|      7664|          6757| 88.16544885177453|
# |               Haiti|      7544|          4832|   64.050901378579|
# |             Finland|      7532|          6980|  92.6712692511949|
# |              Zambia|      7164|          5786| 80.76493579006141|
# |          Luxembourg|      7073|          5750| 81.29506574296622|
# |          Mauritania|      6444|          5291| 82.10738671632527|
# |            Paraguay|      6375|          4974|  78.0235294117647|
# |             Albania|      6016|          3155| 52.44348404255319|
# |             Lebanon|      5672|          1974| 34.80253878702398|
# |             Croatia|      5404|          4688| 86.75055514433753|
# |            Djibouti|      5330|          5057|  94.8780487804878|
# |              Greece|      5123|          1374|26.820222525863752|
# |               Libya|      4879|           652|13.363394138143061|
# +--------------------+----------+--------------+------------------+
# only showing top 100 rows

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import col, when, avg


def seven_day_recovery_average(df: DataFrame) -> DataFrame:
    window_spec = (
        Window.partitionBy("Country_Region").orderBy("Date").rowsBetween(-6, 0)
    )

    df = df.withColumn(
        "7_day_recovery_average", avg(col("Recovered")).over(window_spec)
    )
    return df

# %%
seven_day_recovery_average(full_grouped_df).show(truncate=False)
# Out:
# [Stage 9:>                                                          (0 + 1) / 1]
# +----------+--------------+---------+------+---------+------+---------+----------+-------------+--------------------+----------------------+
# |      Date|Country_Region|Confirmed|Deaths|Recovered|Active|New_cases|New_deaths|New_recovered|          WHO_Region|7_day_recovery_average|
# +----------+--------------+---------+------+---------+------+---------+----------+-------------+--------------------+----------------------+
# |2020-01-22|   Afghanistan|        0|     0|        0|     0|        0|         0|            0|Eastern Mediterra...|                   0.0|
# |2020-01-23|   Afghanistan|        0|     0|        0|     0|        0|         0|            0|Eastern Mediterra...|                   0.0|
# |2020-01-24|   Afghanistan|        0|     0|        0|     0|        0|         0|            0|Eastern Mediterra...|                   0.0|
# |2020-01-25|   Afghanistan|        0|     0|        0|     0|        0|         0|            0|Eastern Mediterra...|                   0.0|
# |2020-01-26|   Afghanistan|        0|     0|        0|     0|        0|         0|            0|Eastern Mediterra...|                   0.0|
# |2020-01-27|   Afghanistan|        0|     0|        0|     0|        0|         0|            0|Eastern Mediterra...|                   0.0|
# |2020-01-28|   Afghanistan|        0|     0|        0|     0|        0|         0|            0|Eastern Mediterra...|                   0.0|
# |2020-01-29|   Afghanistan|        0|     0|        0|     0|        0|         0|            0|Eastern Mediterra...|                   0.0|
# |2020-01-30|   Afghanistan|        0|     0|        0|     0|        0|         0|            0|Eastern Mediterra...|                   0.0|
# |2020-01-31|   Afghanistan|        0|     0|        0|     0|        0|         0|            0|Eastern Mediterra...|                   0.0|
# |2020-02-01|   Afghanistan|        0|     0|        0|     0|        0|         0|            0|Eastern Mediterra...|                   0.0|
# |2020-02-02|   Afghanistan|        0|     0|        0|     0|        0|         0|            0|Eastern Mediterra...|                   0.0|
# |2020-02-03|   Afghanistan|        0|     0|        0|     0|        0|         0|            0|Eastern Mediterra...|                   0.0|
# |2020-02-04|   Afghanistan|        0|     0|        0|     0|        0|         0|            0|Eastern Mediterra...|                   0.0|
# |2020-02-05|   Afghanistan|        0|     0|        0|     0|        0|         0|            0|Eastern Mediterra...|                   0.0|
# |2020-02-06|   Afghanistan|        0|     0|        0|     0|        0|         0|            0|Eastern Mediterra...|                   0.0|
# |2020-02-07|   Afghanistan|        0|     0|        0|     0|        0|         0|            0|Eastern Mediterra...|                   0.0|
# |2020-02-08|   Afghanistan|        0|     0|        0|     0|        0|         0|            0|Eastern Mediterra...|                   0.0|
# |2020-02-09|   Afghanistan|        0|     0|        0|     0|        0|         0|            0|Eastern Mediterra...|                   0.0|
# |2020-02-10|   Afghanistan|        0|     0|        0|     0|        0|         0|            0|Eastern Mediterra...|                   0.0|
# +----------+--------------+---------+------+---------+------+---------+----------+-------------+--------------------+----------------------+
# only showing top 20 rows

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import col, when, avg, lag, row_number


def daily_recovery_growth(df: DataFrame) -> DataFrame:
    window_spec = Window.partitionBy("Country_Region").orderBy("Date")

    df = df.withColumn("prev_recovered", lag("Recovered", 1).over(window_spec))

    df = df.withColumn(
        "daily_recovery_growth", (col("Recovered") - col("prev_recovered"))
    )

    return df


def average_recovery_growth_per_country(df: DataFrame) -> DataFrame:
    return (
        df.groupBy("Country_Region")
        .agg(avg("daily_recovery_growth").alias("avg_recovery_growth"))
        .orderBy(col("avg_recovery_growth").desc())
    )


def peak_recovery_day_per_country(df: DataFrame) -> DataFrame:
    peak_window = Window.partitionBy("Country_Region").orderBy(
        col("daily_recovery_growth").desc()
    )

    df = df.withColumn("rank", row_number().over(peak_window))

    return df.filter(col("rank") == 1).select(
        "Country_Region", "Date", "daily_recovery_growth"
    )

# %%
    daily_recovery_growth_df = daily_recovery_growth(full_grouped_df)

    average_recovery_growth_per_country_df = average_recovery_growth_per_country(
        daily_recovery_growth_df
    )

    peak_recovery_day_per_country_df = peak_recovery_day_per_country(
        daily_recovery_growth_df
    )

    fatest_recovery_country = average_recovery_growth_per_country_df.limit(1)

# %%
daily_recovery_growth_df.show(10)
# Out:
# [Stage 2:>                                                          (0 + 1) / 1]
# +----------+--------------+---------+------+---------+------+---------+----------+-------------+--------------------+--------------+---------------------+
# |      Date|Country_Region|Confirmed|Deaths|Recovered|Active|New_cases|New_deaths|New_recovered|          WHO_Region|prev_recovered|daily_recovery_growth|
# +----------+--------------+---------+------+---------+------+---------+----------+-------------+--------------------+--------------+---------------------+
# |2020-01-22|   Afghanistan|        0|     0|        0|     0|        0|         0|            0|Eastern Mediterra...|          NULL|                 NULL|
# |2020-01-23|   Afghanistan|        0|     0|        0|     0|        0|         0|            0|Eastern Mediterra...|             0|                    0|
# |2020-01-24|   Afghanistan|        0|     0|        0|     0|        0|         0|            0|Eastern Mediterra...|             0|                    0|
# |2020-01-25|   Afghanistan|        0|     0|        0|     0|        0|         0|            0|Eastern Mediterra...|             0|                    0|
# |2020-01-26|   Afghanistan|        0|     0|        0|     0|        0|         0|            0|Eastern Mediterra...|             0|                    0|
# |2020-01-27|   Afghanistan|        0|     0|        0|     0|        0|         0|            0|Eastern Mediterra...|             0|                    0|
# |2020-01-28|   Afghanistan|        0|     0|        0|     0|        0|         0|            0|Eastern Mediterra...|             0|                    0|
# |2020-01-29|   Afghanistan|        0|     0|        0|     0|        0|         0|            0|Eastern Mediterra...|             0|                    0|
# |2020-01-30|   Afghanistan|        0|     0|        0|     0|        0|         0|            0|Eastern Mediterra...|             0|                    0|
# |2020-01-31|   Afghanistan|        0|     0|        0|     0|        0|         0|            0|Eastern Mediterra...|             0|                    0|
# +----------+--------------+---------+------+---------+------+---------+----------+-------------+--------------------+--------------+---------------------+
# only showing top 10 rows

# %%
average_recovery_growth_per_country_df.show(10)
# Out:
# [Stage 7:>                                                          (0 + 1) / 1]
# +--------------+-------------------+
# |Country_Region|avg_recovery_growth|
# +--------------+-------------------+
# |        Brazil|  9875.085561497326|
# |            US|  7089.860962566845|
# |         India|  5086.449197860962|
# |        Russia| 3220.5828877005347|
# |         Chile| 1710.9839572192514|
# |        Mexico| 1624.6524064171124|
# |  South Africa| 1470.1871657754011|
# |          Peru| 1457.4705882352941|
# |          Iran| 1364.4064171122996|
# |      Pakistan|  1288.909090909091|
# +--------------+-------------------+
# only showing top 10 rows

# %%
DAY_WISE_FILE_PATH = "hdfs:///data/covid/staging/day_wise/part-00000-878258c0-6596-41f8-b637-87ebe5df7682-c000.snappy.parquet"

# %%
day_wise_df = read_data(DAY_WISE_FILE_PATH)

# %%
day_wise_df.show(1)
# Out:
# +----------+---------+------+---------+------+---------+----------+-------------+------------------+---------------------+----------------------+---------------+
# |      Date|Confirmed|Deaths|Recovered|Active|New_cases|New_deaths|New_recovered|Deaths___100_Cases|Recovered___100_Cases|Deaths___100_Recovered|No_of_countries|
# +----------+---------+------+---------+------+---------+----------+-------------+------------------+---------------------+----------------------+---------------+
# |2020-01-22|      555|    17|       28|   510|        0|         0|            0|              3.06|                 5.05|                 60.71|              6|
# +----------+---------+------+---------+------+---------+----------+-------------+------------------+---------------------+----------------------+---------------+
# only showing top 1 row

# %%
def global_daily_average_new_cases(df: DataFrame) -> DataFrame:
    return df.groupBy("Date").agg(avg("New_cases").alias("Avg_New_Cases"))

# %%
global_daily_average_new_cases(day_wise_df).show(10)
# Out:
# [Stage 2:>                                                          (0 + 1) / 1]
# +----------+-------------+
# |      Date|Avg_New_Cases|
# +----------+-------------+
# |2020-07-24|     281164.0|
# |2020-04-30|      83681.0|
# |2020-03-07|       4038.0|
# |2020-03-13|      14405.0|
# |2020-02-04|       4011.0|
# |2020-02-15|       2075.0|
# |2020-05-23|     105289.0|
# |2020-02-12|       1886.0|
# |2020-05-08|      92997.0|
# |2020-05-24|      95326.0|
# +----------+-------------+
# only showing top 10 rows

# %%
def detech_spike_days(df: DataFrame)-> DataFrame:
    stats = df.select(
        mean("New_cases").alias("mean_cases"),
        stddev("New_cases").alias("std_cases")
    ).collect()[0]
    
    mean_cases = stats["mean_cases"]
    std_cases = stats["std_cases"]

    df = df.withColumn(
        "z_score",
        (col("New_cases") - mean_cases) / std_cases
    )

    return df.filter(col("z_score") > 2)

# %%
detech_spike_days(day_wise_df).show(100, truncate=False)
# Out:
# +----------+---------+------+---------+-------+---------+----------+-------------+------------------+---------------------+----------------------+---------------+------------------+
# |Date      |Confirmed|Deaths|Recovered|Active |New_cases|New_deaths|New_recovered|Deaths___100_Cases|Recovered___100_Cases|Deaths___100_Recovered|No_of_countries|z_score           |
# +----------+---------+------+---------+-------+---------+----------+-------------+------------------+---------------------+----------------------+---------------+------------------+
# |2020-07-16|13812525 |589760|7634241  |5588524|252544   |5799      |151921       |4.27              |55.27                |7.73                  |187            |2.1883569556532345|
# |2020-07-17|14054563 |596503|7793760  |5664300|242038   |6743      |159519       |4.24              |55.45                |7.65                  |187            |2.0488263217215237|
# |2020-07-22|15227725 |623540|8541255  |6062930|280647   |6983      |176269       |4.09              |56.09                |7.3                   |187            |2.561594096847111 |
# |2020-07-23|15510481 |633506|8710969  |6166006|282756   |9966      |169714       |4.08              |56.16                |7.27                  |187            |2.5896038157660124|
# |2020-07-24|15791645 |639650|8939705  |6212290|281164   |6144      |228736       |4.05              |56.61                |7.16                  |187            |2.5684603958898196|
# |2020-07-25|16047190 |644517|9158743  |6243930|255545   |4867      |219038       |4.02              |57.07                |7.04                  |187            |2.228213364603269 |
# +----------+---------+------+---------+-------+---------+----------+-------------+------------------+---------------------+----------------------+---------------+------------------+

# %%
def peak_death_day_globally(df: DataFrame) -> DataFrame:
    df = df.groupby("Date").agg(sum("New_deaths").alias("Total_Deaths"))
    return df.orderBy(col("Total_Deaths").desc()).limit(1)

# %%
peak_death_day_globally(day_wise_df).show()
# Out:
# +----------+------------+
# |      Date|Total_Deaths|
# +----------+------------+
# |2020-07-23|        9966|
# +----------+------------+

# %%
def death_growth_rate_month_over_month(df: DataFrame) -> DataFrame:
    df = (
        df.withColumn("Year", year("Date"))
          .withColumn("Month", month("Date"))
    )

    df = (
        df.groupBy("Year", "Month")
        .agg(sum("New_Deaths").alias("Monthly_Deaths"))
        .orderBy("Year","Month")
    )

    window_spec = Window.orderBy("Year", "Month")

    df = df.withColumn(
        "Prev_Month_Deaths",
        lag("Monthly_Deaths").over(window_spec)
    )

    return df.withColumn(
        "MoM_Death_Growth_Rate",
        when(
            col("Prev_Month_Deaths") != 0,
            (
                (col("Monthly_Deaths") - col("Prev_Month_Deaths"))
                / col("Prev_Month_Deaths")
            ) * 100
        )
    )

# %%
death_growth_rate_month_over_month(day_wise_df).show()
# Out:
# 26/05/10 15:16:22 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/05/10 15:16:22 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/05/10 15:16:22 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/05/10 15:16:22 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/05/10 15:16:22 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/05/10 15:16:23 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/05/10 15:16:23 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/05/10 15:16:23 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/05/10 15:16:23 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# +----+-----+--------------+-----------------+---------------------+
# |Year|Month|Monthly_Deaths|Prev_Month_Deaths|MoM_Death_Growth_Rate|
# +----+-----+--------------+-----------------+---------------------+
# |2020|    1|           196|             NULL|                 NULL|
# |2020|    2|          2723|              196|   1289.2857142857142|
# |2020|    3|         41542|             2723|     1425.59676827029|
# |2020|    4|        190226|            41542|   357.91247412257474|
# |2020|    5|        138902|           190226|  -26.980538937894927|
# |2020|    6|        137604|           138902|  -0.9344717858634145|
# |2020|    7|        142826|           137604|   3.7949478212842647|
# +----+-----+--------------+-----------------+---------------------+
# 26/05/10 15:21:50 WARN Dispatcher: Message RemoteProcessDisconnected(192.168.31.145:38688) dropped. Could not find MapOutputTracker.
# 26/05/10 15:21:50 WARN JavaUtils: Attempt to delete using native Unix OS command failed for path = /tmp/spark-021ca833-c7cb-400a-ba44-a03b33ec3df7. Falling back to Java IO way
# java.io.IOException: Failed to delete: /tmp/spark-021ca833-c7cb-400a-ba44-a03b33ec3df7
# 	at org.apache.spark.network.util.JavaUtils.deleteRecursivelyUsingUnixNative(JavaUtils.java:199)
# 	at org.apache.spark.network.util.JavaUtils.deleteRecursively(JavaUtils.java:116)
# 	at org.apache.spark.network.util.JavaUtils.deleteRecursively(JavaUtils.java:94)
# 	at org.apache.spark.util.SparkFileUtils.deleteRecursively(SparkFileUtils.scala:121)
# 	at org.apache.spark.util.SparkFileUtils.deleteRecursively$(SparkFileUtils.scala:120)
# 	at org.apache.spark.util.Utils$.deleteRecursively(Utils.scala:1048)
# 	at org.apache.spark.util.ShutdownHookManager$.$anonfun$new$4(ShutdownHookManager.scala:70)
# 	at org.apache.spark.util.ShutdownHookManager$.$anonfun$new$4$adapted(ShutdownHookManager.scala:67)
# 	at scala.collection.ArrayOps$.foreach$extension(ArrayOps.scala:1324)
# 	at org.apache.spark.util.ShutdownHookManager$.$anonfun$new$2(ShutdownHookManager.scala:67)
# 	at org.apache.spark.util.SparkShutdownHook.run(ShutdownHookManager.scala:231)
# 	at org.apache.spark.util.SparkShutdownHookManager.$anonfun$runAll$2(ShutdownHookManager.scala:205)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:1937)
# 	at org.apache.spark.util.SparkShutdownHookManager.$anonfun$runAll$1(ShutdownHookManager.scala:205)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at scala.util.Try$.apply(Try.scala:217)
# 	at org.apache.spark.util.SparkShutdownHookManager.runAll(ShutdownHookManager.scala:205)
# 	at org.apache.spark.util.SparkShutdownHookManager$$anon$2.run(ShutdownHookManager.scala:184)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Executors.java:572)
# 	at java.base/java.util.concurrent.FutureTask.run(FutureTask.java:317)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1144)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:642)
# 	at java.base/java.lang.Thread.run(Thread.java:1583
# |84013187|  US| USA|  840|   0|   Lumpkin|       Georgia|            US|       34.57286511|      -84.00425681|Lumpkin, Georgia, US|2020-05-01|       46|     2|
# +--------+----+----+-----+----+----------+--------------+--------------+------------------+------------------+--------------------+----------+---------+------+
# only showing top 20 rows

# %%
def aggregate_county_data_to_state_level(df: DataFrame)-> DataFrame:
    return df.groupBy("Date","Province_State").agg(sum("Confirmed").alias("Total_Confirmed"), sum("Deaths").alias("Deaths"))

# %%
aggregate_county_data_to_state_level(usa_county_wise_df).show(100)
# Out:
# [Stage 5:=============================>                             (1 + 1) / 2]
# +----------+--------------------+---------------+------+
# |      Date|      Province_State|Total_Confirmed|Deaths|
# +----------+--------------------+---------------+------+
# |2020-05-01|            Colorado|          15793|   817|
# |2020-05-05|            Virginia|          20257|   713|
# |2020-05-09|            Missouri|           9988|   581|
# |2020-05-09|           Wisconsin|           9939|   398|
# |2020-05-11|             Florida|          40982|  1735|
# |2020-05-14|      South Carolina|           8189|   488|
# |2020-05-14|          Washington|          17773|   983|
# |2020-05-15|             Arizona|          13169|   650|
# |2020-05-16|       New Hampshire|           3556|   185|
# |2020-05-17|          Washington|          18433|  1001|
# |2020-05-19|Northern Mariana ...|             21|     2|
# |2020-05-25|        North Dakota|           2457|    48|
# |2020-05-25|           Tennessee|          20535|   334|
# |2020-05-28|            Virginia|          41401|  1338|
# |2020-05-29|            Colorado|          25598|  1436|
# |2020-05-30|      Grand Princess|            103|     0|
# |2020-06-02|           Louisiana|          40746|  2724|
# |2020-06-09|              Kansas|          10609|   418|
# |2020-06-18|               Texas|         101259|  2129|
# |2020-06-21|            New York|         387936| 31739|
# |2020-06-29|       New Hampshire|           5760|   368|
# |2020-07-09|              Hawaii|           1130|    19|
# |2020-07-27|            Illinois|         173894|  7417|
# |2020-05-01|              Nevada|           5248|   243|
# |2020-05-03|      North Carolina|          11770|   435|
# |2020-05-06|            Oklahoma|           4202|   259|
# |2020-05-07|            Missouri|           9683|   549|
# |2020-05-15|             Florida|          44138|  1918|
# |2020-05-16|                Iowa|          14328|   347|
# |2020-05-21|        South Dakota|           4177|   604|
# |2020-05-22|         Connecticut|          39640|  3635|
# |2020-05-23|           Wisconsin|          14877|   507|
# |2020-05-28|           Minnesota|          22947|   973|
# |2020-06-06|         Mississippi|          17039|   811|
# |2020-06-06|               Texas|          74470|  1833|
# |2020-06-08|            Nebraska|          15786|   188|
# |2020-06-08|            Oklahoma|           7205|   348|
# |2020-06-18|               Idaho|           3743|   130|
# |2020-06-20|            Oklahoma|          10038|   368|
# |2020-06-21|            Nebraska|          17812|   243|
# |2020-06-28|             Georgia|          77210|  2733|
# |2020-07-04|       West Virginia|           3205|    94|
# |2020-07-14|         Connecticut|          47530|  4372|
# |2020-07-14|               Maine|           3566|   114|
# |2020-07-16|            Maryland|          75664|  3444|
# |2020-05-03|District of Columbia|           5016|   252|
# |2020-05-03|         Mississippi|           7550|   303|
# |2020-05-04|         Puerto Rico|           1843|     0|
# |2020-05-05|      Grand Princess|            103|     0|
# |2020-05-08|      American Samoa|              0|     0|
# |2020-05-16|    Diamond Princess|             49|     0|
# |2020-05-18|             Florida|          46442|  1998|
# |2020-05-26|             Vermont|            967|    54|
# |2020-06-05|             Montana|            541|    18|
# |2020-06-12|              Kansas|          10973|   425|
# |2020-06-18|            Kentucky|          13197|   520|
# |2020-06-18|               Maine|           2878|   102|
# |2020-07-02|            Kentucky|          16079|   581|
# |2020-07-02|           Minnesota|          37210|  1465|
# |2020-07-05|      Virgin Islands|            111|     6|
# |2020-07-10|         Connecticut|          47287|  4348|
# |2020-07-14|        Pennsylvania|         101266|  6931|
# |2020-07-15|            Arkansas|          30297|   335|
# |2020-07-24|                Guam|            337|     5|
# |2020-07-24|             Alabama|          76005|  1396|
# |2020-07-25|             Montana|           3259|    46|
# |2020-07-25|             Vermont|           1396|    56|
# |2020-07-26|            Illinois|         172663|  7399|
# |2020-05-02|            Kentucky|           4879|   248|
# |2020-05-09|            Virginia|          23196|   827|
# |2020-05-16|            Kentucky|           7688|   334|
# |2020-05-17|               Texas|          48396|  1343|
# |2020-06-01|           Minnesota|          25208|  1064|
# |2020-06-17|               Maine|           2836|   102|
# |2020-06-18|              Kansas|          11753|   438|
# |2020-06-19|          New Mexico|          10260|   464|
# |2020-06-21|            Illinois|         136762|  6647|
# |2020-06-24|                Ohio|          46759|  2755|
# |2020-07-01|    Diamond Princess|             49|     0|
# |2020-07-04|          Washington|          35247|  1354|
# |2020-07-07|             Alabama|          45785|  1008|
# |2020-07-07|        Rhode Island|          17154|     0|
# |2020-07-09|      Virgin Islands|            144|     6|
# |2020-07-09|             Vermont|           1272|    56|
# |2020-07-10|                Utah|          28223|   219|
# |2020-07-10|             Vermont|           1277|    56|
# |2020-07-11|              Alaska|           1385|    51|
# |2020-07-12|             Wyoming|           1862|     1|
# |2020-07-14|             Florida|         291629|  4418|
# |2020-07-21|         Connecticut|          48096|  4406|
# |2020-07-22|        Pennsylvania|         108223|  7077|
# |2020-07-24|              Nevada|          40885|   722|
# |2020-05-04|              Hawaii|            621|    17|
# |2020-05-07|Northern Mariana ...|             15|     2|
# |2020-05-11|        Pennsylvania|          60459|  3832|
# |2020-05-17|                Guam|            154|     5|
# |2020-05-20|            New York|         354370| 29389|
# |2020-05-22|             Arizona|          15624|   773|
# |2020-05-24|                Utah|           8392|   101|
# |2020-05-30|           Louisiana|          39577|  2681|
# +----------+--------------------+---------------+------+
# only showing top 100 rows

# %%
def top_10_affected_states(df: DataFrame) -> DataFrame:
    df = (
        df.groupBy("Province_State")
          .agg(
              sum("Confirmed").alias("Total_Confirmed"),
              sum("Deaths").alias("Total_Deaths")
          )
    )

    return (
        df.orderBy(col("Total_Confirmed").desc())
                .limit(10)
    )

# %%
top_10_affected_states(usa_county_wise_df).show()
# Out:
# +--------------+---------------+------------+
# |Province_State|Total_Confirmed|Total_Deaths|
# +--------------+---------------+------------+
# |      New York|       39808447|     3176945|
# |    California|       17618695|      481757|
# |    New Jersey|       16506714|     1221339|
# |         Texas|       12698726|      210547|
# |       Florida|       12657802|      292541|
# |      Illinois|       11900637|      541672|
# | Massachusetts|        9874030|      666157|
# |  Pennsylvania|        8096993|      537261|
# |       Georgia|        6859759|      222262|
# |      Michigan|        6690544|      576093|
# +--------------+---------------+------------+

# %%
def detech_data_skew_across_state(df: DataFrame) -> DataFrame:
    state_counts = (
        df.groupBy("Province_State")
          .count()
    )

    stats = state_counts.select(
        mean("count").alias("mean"),
        stddev("count").alias("std")
    ).collect()[0]

    mean_val = stats["mean"]
    std_val = stats["std"]
    
    skew_df = state_counts.withColumn(
        "z_score",
        (col("count") - mean_val) / std_val
    )

    return skew_df.filter(col("z_score") > 2)

# %%
detech_data_skew_across_state(usa_county_wise_df).show()
# Out:
# +--------------+-----+------------------+
# |Province_State|count|           z_score|
# +--------------+-----+------------------+
# |         Texas|48128| 4.142461036456502|
# |       Georgia|30268|2.1590616350943774|
# +--------------+-----+------------------+

# %%
from pyspark import RDD
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("rdd_based_analysis").getOrCreate()

FULL_GROUPED_FILE_PATH = "hdfs:///data/covid/staging/full_grouped"


def read_data(file_path):
    return spark.read.parquet(file_path)


def total_confirmed_cases_per_country(rdd: RDD) -> RDD:
    country_confirmed_rdd = rdd.map(
        lambda row: (row["Country_Region"], row["Confirmed"])
    )
    return country_confirmed_rdd.reduceByKey(lambda x, y: x + y)


def total_deaths_per_country(rdd: RDD) -> RDD:
    country_deaths = rdd.map(lambda row: (row["Country_Region"], row["Deaths"]))

    return country_deaths.reduceByKey(lambda x, y: x + y)


def death_percentage(rdd: RDD) -> RDD:
    country_stats = rdd.map(
        lambda row: (row["Country_Region"], (row["Confirmed"], row["Deaths"]))
    )

    aggregated_stats = country_stats.reduceByKey(
        lambda x, y: (x[0] + y[0], x[1] + y[1])
    )

    return aggregated_stats.mapValues(
        lambda x: (x[0], x[1], (x[1] / x[0]) * 100 if x[0] != 0 else 0)
    )
# Out:
# 26/05/10 19:29:08 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.

# %%
full_grouped_rdd = read_data(FULL_GROUPED_FILE_PATH)

# %%
full_grouped_rdd = full_grouped_rdd.rdd

# %%
    total_confirmed_per_country_df = spark.createDataFrame(
        total_confirmed_cases_per_country(full_grouped_rdd),
        ["Country_Region", "Total_Confirmed"],
    )

# %%
total_confirmed_per_country_df.show()
# Out:
# +-------------------+---------------+
# |     Country_Region|Total_Confirmed|
# +-------------------+---------------+
# |        Afghanistan|        1936390|
# |            Albania|         196702|
# |            Algeria|        1179755|
# |            Andorra|          94404|
# |             Angola|          22662|
# |Antigua and Barbuda|           4487|
# |          Argentina|        4450658|
# |            Armenia|        1587173|
# |          Australia|         960247|
# |            Austria|        2034986|
# |         Azerbaijan|        1134717|
# |            Bahamas|          12100|
# |            Bahrain|        1755206|
# |         Bangladesh|        8754729|
# |           Barbados|          10652|
# |            Belarus|        4426759|
# |            Belgium|        6281116|
# |             Belize|           2636|
# |              Benin|          64406|
# |             Bhutan|           4971|
# +-------------------+---------------+
# only showing top 20 rows

# %%
    total_deaths_per_country_df = spark.createDataFrame(
        total_deaths_per_country(full_grouped_rdd), ["Country_Region", "Total_Deaths"]
    )

# %%
total_confirmed_per_country_df
